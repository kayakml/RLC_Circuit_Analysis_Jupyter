# %% [markdown]
# # Book: Circuit Analysis I With MATLAB Applications

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
def rad2deg(rad):
    return rad*180/np.pi

def deg2rad(deg):
    return deg*np.pi/180

# %% [markdown]
# ## Example 7.1
#
# VAB = ?
#
# ![image.png](attachment:image.png)

# %% [raw]
# Öncelikle 10A'lik akım kaynağını açık devre edip Va1 ve Vb1 gerilimlerini bulacağız. Akabinde 5A'lilk kaynağı açık devre edip Va2 ve Vb2 gerilimlerini bulacağız.
#
# VA = Va1 + Va2
# VB = Vb1 + Vb2
# VAB = VA-VB

# %% [markdown]
# ### 10A'lik kaynak açık devre

# %%
Z1 = 4-6j
Z2 = 2 + 3j + 8 - 3j

# %%
I2 = (Z1/(Z1+Z2))*5
I1 = (Z2/(Z1+Z2))*5

# %%
Va1 = I1*Z1
Vb1 = I2*(8-3j)
Vab1 = Va1-Vb1
Vab1
# Out:
# (7.8448275862069+3.362068965517242j)

# %% [markdown]
# ### 5A'lik kaynak açık devre

# %%
Z3 = 8-3j
Z4 = 4-6j+2+3j

# %%
I3 = (Z4/(Z3+Z4))*10
I4 = (Z3/(Z3+Z4))*10
# Out:
# (4.3965517241379315-0.2586206896551726j)

# %%
Vb2 = 0
Va2 = I4*(2+3j)
Vab2 = Va2-Vb2
Vab2
# Out:
# (10.43103448275862+17.32758620689655j)

# %% [markdown]
# ### Süperpozisyon İlkesini Uygulayalım

# %%
VA = Va1+Va2
VB = Vb1+Vb2
VAB = VA-VB
VAB
# Out:
# (18.27586206896552+20.689655172413794j)

# %% [markdown]
# ## Example 7.9
#
# Compute and sketch all phasor voltages and plot them.
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Önce birinci gözde bir göz analizi yapalım:
#
# ### $ V_s - i_1*2 - [(i_1 - i_2)*(-5j)] = 0 $
#
# ### $ V_s - i_1*2 + i_1*5j - i_2*5j = 0 $
#
# # $ V_s -i_1*(2-5j) - i_2*5j = 0$
#
# Şimdi de ikinci gözde bir göz analizi yapalım:
#
# ### $ (i_2 - i_1)*(-5j) + i_2*3j + i_2*5 = 0 $
#
# ### $   i_2*(-5j) + i_1*5j + i_2*3j + i_2*5 = 0  $
#
# ### $   i_2*(-5j+3j+5) + i_1*5j = 0$
#
# ### $   i_2*(-5+2j) = i_1*5j $
#
# # $   i_2 = i_1*(\frac{5j}{-5+2j})$
#
# $i_2$ değerini birinci göz denkleminde yerine yazalım
#
# ### $  V_s -i_1*(2-5j) - i_1*(\frac{5j}{-5+2j})*5j = 0$
#
# ### $  V_s - i_1*((2-5j)+(5j*(\frac{5j}{-5+2j})) = 0 $
#
# ### $  V_s = i_1*((2-5j)+(5j*(\frac{5j}{-5+2j}))$
#
# # $  i_1 = \frac{V_s}{((2-5j)+(5j*(\frac{5j}{-5+2j}))}$

# %%
I1 = 1/((2-5j)+(5j*(5j/(-5+2j))))
I1
# Out:
# (0.12482946793997271+0.06480218281036833j)

# %%
I2 = I1 * (5j/(-5+2j))
I2
# Out:
# (0.09890859481582537-0.08526603001364258j)

# %%
Vc1 = (I1-I2)*(-5j)
Vc1
# Out:
# (0.7503410641200545-0.1296043656207367j)

# %%
Vr2 = I2*5
Vr2
# Out:
# (0.49454297407912684-0.4263301500682129j)

# %%
Vl = Vc1-Vr2
Vl
# Out:
# (0.2557980900409277+0.2967257844474762j)

# %%
f = 1
w = 2 * np.pi* f # = 2*pi*f
t = np.linspace(0,1,1000)

# %%
def vs(t):
    return np.cos(w*t)

# %% [markdown]
# Komplex formdaki çıkış voltajlarını(Vc1,Vr2,Vl) fazör forma çevirerek zamana ve frekansa bağlı fonksiyonlar elde edelim:
#
# ## $Z = a + jb $
#
# ## $ Z = r*cos(wt + \theta)$
#
# ## $ r = \sqrt{(a^2)+(b^2)}$
#
# ## $ \theta = tan^-1(\frac{b}{a})$

# %%
r_vc1 = np.sqrt(Vc1.real**2+Vc1.imag**2)
theta_vc1 = rad2deg(np.arctan(Vc1.imag/Vc1.real))

# %%
def vc1(t):
    return r_vc1*np.cos(w*t+theta_vc1)

# %%
r_vr2 = np.sqrt(Vr2.real**2+Vr2.imag**2)
theta_vr2 = rad2deg(np.arctan(Vr2.imag/Vr2.real))

# %%
def vr2(t):
    return r_vr2*np.cos(w*t+theta_vr2)

# %%
r_vl = np.sqrt(Vl.real**2+Vl.imag**2)
theta_vl = rad2deg(np.arctan(Vl.imag/Vl.real))

# %%
def vl(t):
    return r_vl*np.cos(w*t+theta_vl)

# %%
fig,ax = plt.subplots(figsize=(20,10))
ax.plot(t,vs(t),label="Vs(t)",lw = 4)
ax.plot(t,vl(t),label="Vl(t)")
ax.plot(t,vr2(t),label="Vr2(t)")
ax.plot(t,vc1(t),label="Vc1(t)")
ax.legend()

# %%
f = 30e3
w = 2*np.pi*f
C0 = 2.3e-9
R1 = 1600
L1 = 115e-3
C1 = 215e-12
R2 = 3.3e3

t = np.linspace(0,0.1,1000)

# %%
Xc0 = (1/1j)*(1/(w*C0))

# %%
X1 = 1600+((w*L1)*(1j))+((1/1j)*(1/(w*C1)))
X1
# Out:
# (1600-2998.195665718071j)

# %%
Xes = X1*Xc0/(X1+Xc0)
Xess = Xes + R2
Xess
# Out:
# (3577.2761778009976-1387.2861093168362j)

# %%
I = 1/Xess
Vr2 = I*R2
Vr2
# Out:
# (0.8018909327795513+0.31097743001660905j)

# %%
r_vr2 = np.sqrt(Vr2.real**2+Vr2.imag**2)
r_vr2
# Out:
# 0.8600790836044053

# %%
theta_vr2 = rad2deg(np.arctan(Vr2.imag/Vr2.real))
theta_vr2
# Out:
# 21.196548967903915

# %%
def vr2(t):
    return r_vr2*np.cos(w*t+theta_vr2)

# %%
def vs(t):
    return np.cos(w*t)

# %%
plt.plot(t,vs(t),t,vr2(t))
# Out:
# [<matplotlib.lines.Line2D at 0x7f064efe27d0>,
#  <matplotlib.lines.Line2D at 0x7f064eb20dd0>]
